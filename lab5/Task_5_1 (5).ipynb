# %% [markdown]
# ## Task 5.

# %%
# !pip install mnist

import numpy as np
import math
import mnist

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
x = np.array([1.3, 0.32, 0.21]) # softmax
y = 2 # sigmoid
a = -9 # relu
z = 4
33
# Out:
# 33

# %%
def softmax(x):
    return np.exp(x) / sum(np.exp(x))
print(softmax(x))
# Out:
# [0.58427337 0.21928428 0.19644234]

# %% [markdown]
# ![Zrzut ekranu 2022-03-24 o 11.33.41.png](data:image/png;base64,...)

# %%
def sigmoid(y):
  return 1 / (1 + math.exp(-y))
print(sigmoid(y))
# Out:
# 0.8807970779778823

# %%
def relu(a):
    return max(0.0, a)
print(relu(a))
# Out:
# 0.0

# %%
def tanh(z):
    return np.sinh(z) / np.cosh(z) or -1j * np.tan(1j*z)
print(tanh(z))
# Out:
# 0.9993292997390669

# %%
train_images = mnist.train_images()
train_labels = mnist.train_labels()
test_images = mnist.test_images()
test_labels = mnist.test_labels()

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
train_images = (train_images / 255) - 0.5 # RGB 255 col 
test_images = (test_images / 255) - 0.5

# %%
print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
train_images = train_images.reshape((-1, 784)) # 28*28
test_images = test_images.reshape((-1, 784))

# %%
print(train_images.shape)
# Out:
# (60000, 784)

# %%
model = Sequential([
  Dense(70, activation='relu', input_shape=(784,)), 
  Dense(40, activation='relu' ),
  Dense(10, activation='softmax')

# %%
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# %%
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=5,
  batch_size=30,
)
# Out:
# Epoch 1/5
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.3529 - accuracy: 0.8928
# Epoch 2/5
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.1788 - accuracy: 0.9457
# Epoch 3/5
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.1372 - accuracy: 0.9581
# Epoch 4/5
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.1152 - accuracy: 0.9650
# Epoch 5/5
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.1008 - accuracy: 0.9683

# %%
#Task 1.

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 70)                54950
#
#  dense_4 (Dense)             (None, 40)                2840
#
#  dense_5 (Dense)             (None, 10)                410
#
# ...
# Total params: 58,200
# Trainable params: 58,200
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=100,
  batch_size=30,
)

# %%
#task 3.
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=5,
  batch_size=20,
)
#relaod from 23 and run this
# Out:
# Epoch 1/5
# 3000/3000 [==============================] - 8s 2ms/step - loss: 0.1042 - accuracy: 0.9674
# Epoch 2/5
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0914 - accuracy: 0.9712
# Epoch 3/5
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0835 - accuracy: 0.9734
# Epoch 4/5
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0765 - accuracy: 0.9762
# Epoch 5/5
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0716 - accuracy: 0.9770

# %%
#task 4
from keras.layers import Dropout

model = Sequential([
  Dense(80, activation='relu', input_shape=(784,)),
  Dense(60, activation='relu'),
  Dropout(0.2, input_shape=(784,)),
  Dense(60, activation='relu'),
  Dense(10, activation='softmax')
])


model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)
  

model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=5,
  batch_size=30,
)
# Out:
# Epoch 1/5
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.4130 - accuracy: 0.8736
# Epoch 2/5
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.2095 - accuracy: 0.9362
# Epoch 3/5
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1728 - accuracy: 0.9476
# Epoch 4/5
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.1499 - accuracy: 0.9540
# Epoch 5/5
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1339 - accuracy: 0.9589

# %%
#task-5

model_1 = Sequential([
  Dense(256, activation='linear', input_shape=(784,)), 
  Dense(256, activation='linear' ),
  Dense(256, activation='linear' ),
  Dense(128, activation='linear' ),
  Dense(128, activation='linear' ),
  Dense(128, activation='linear' ),
  Dense(64, activation='linear' ),
  Dense(64, activation='linear' ),
  Dense(64, activation='linear' ),
  Dense(10, activation='softmax')
])

model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=10,
  batch_size=30,
)
# Out:
# Epoch 1/10
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.1244 - accuracy: 0.9622
# Epoch 2/10
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.1139 - accuracy: 0.9648
# Epoch 3/10
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1057 - accuracy: 0.9666
# Epoch 4/10
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.1000 - accuracy: 0.9689
# Epoch 5/10
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.0926 - accuracy: 0.9710
# Epoch 6/10
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.0881 - accuracy: 0.9724
# Epoch 7/10
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.0848 - accuracy: 0.9738
# Epoch 8/10
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.0806 - accuracy: 0.9746
# Epoch 9/10
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.0802 - accuracy: 0.9742
# Epoch 10/10
# ...

# %%
model_x = Sequential([
  Dense(256, activation='linear', input_shape=(784,)),
  Dense(256, activation='linear'),
  Dense(256, activation='linear'),
  Dense(128, activation='linear'),
  Dense(128, activation='linear'),
  Dense(128, activation='linear'),
  Dense(64, activation='linear'),
  Dense(64, activation='linear'),
  Dense(64, activation='linear'),
  Dense(10, activation='linear'),
])

model_y = Sequential([
  Dense(256, activation='linear', input_shape=(784,)),
  Dense(128, activation='linear'),
  Dense(64, activation='linear'),
  Dense(10, activation='linear'),
])

# %%
print(model_x.summary())

# %%
print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_41 (Dense)            (None, 80)                62800
#
#  dense_42 (Dense)            (None, 60)                4860
#
#  dropout_2 (Dropout)         (None, 60)                0
#
#  dense_43 (Dense)            (None, 60)                3660
#
#  dense_44 (Dense)            (None, 10)                610
#
# ...
# Total params: 71,930
# Trainable params: 71,930
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ##### 4.1. 📚 Task 1.
# Look for information about model plotting (https://keras.io/api/utils/model_plotting_utils/) that represents the architecture of the neural network and show it below. Use the network architecture shown during tutorial.
# ##### 4.2. 📚 Task 2.
# Reload the model, modify the parameters related to the training process. Change the number of epochs to 100. Do you see moment when the classification accuracy stabilizes?
# ##### 4.3. 📚 Task 3.
# Reload the model, modify the parameters related to the training process. Leave the number of epochs (n = 5), but modify the batch size to 20. Did this affect the  parameters of the model?
# ##### 4.4. 📚 Task 4.
# Suggest a different neural network architecture. Change the number of layers, modify the number of nodes. Add a new Dropout layer type. Did you manage to achieve better model parameters?
# ##### 4.5. 📚 Task 5.
# Recreate the two neural network architectures (arch1 & arch2). Define the activation function as linear (also for the network output) and train with epochs of 10. How would you describe the learning flow? Why do neural networks, despite their differentiation, behave similarly during training and their parameters (classification accuracy, val loss) are the same regardless of the epoch? (https://stackoverflow.com/questions/9782071/why-must-a-nonlinear-activation-function-be-used-in-a-backpropagation-neural-net)
